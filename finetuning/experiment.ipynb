# %%
import boto3

# %%
s3 = boto3.client("s3")

# %%
response = s3.list_objects_v2(Bucket="llm-finetune-dataset-vinayakan", Prefix="datasets/")

# %%
response

# %%
for obj in response.get("Contents",[]):
    print(obj)

# %%
for obj in response.get("Contents",[]):
    print(obj["Key"])

# %%
# !which python

# %%
# command to activate env
# sh-4.2$ source /home/ec2-user/anaconda3/bin/activate python3

# %%
from datasets import load_dataset

# %%
dataset_path = "s3://llm-finetune-dataset-vinayakan/datasets/pharma_instruction_data.csv"

# %%
dataset = load_dataset("csv",data_files={"train":dataset_path})
